# %%
import pandas as pd
import numpy as np

# %%
df = [pd.read_csv('jurassic_park.csv'),pd.read_csv('pbdb_data.csv')]
df[0]
# Out:
# /tmp/ipykernel_368/387501768.py:1: DtypeWarning: Columns (3,21,22,23,40,44,47,49,50,51,52,53,60,63,64,65,70,71,72,74,78,79,80,81,82,83,84,85,86,87,88,89,93,94,95,96,97,104,109,110,111) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = [pd.read_csv('jurassic_park.csv'),pd.read_csv('pbdb_data.csv')]
#                  name         diet  \
# 0            aardonyx  herbivorous
# 1         abelisaurus  carnivorous
# 2       achelousaurus  herbivorous
# 3        achillobator  carnivorous
# 4    acrocanthosaurus  carnivorous
# ..                ...          ...
# 304     yuanmousaurus  herbivorous
# 305     yunnanosaurus   omnivorous
# 306          zalmoxes  herbivorous
# 307     zephyrosaurus  herbivorous
# 308      zuniceratops  herbivorous
#
#                                          period      lived_in            type  \
# 0      Early Jurassic 199-189 million years ago  South Africa        sauropod
# 1       Late Cretaceous 74-70 million years ago     Argentina  large theropod
# 2       Late Cretaceous 83-70 million years ago           USA     ceratopsian
# 3       Late Cretaceous 99-84 million years ago      Mongolia  large theropod
# 4    Early Cretaceous 115-105 million years ago           USA  large theropod
# ..                                          ...           ...             ...
# 304      Mid Jurassic 180-159 million years ago         China        sauropod
# 305    Early Jurassic 205-190 million years ago         China        sauropod
# 306        Late Cretaceous 69 million years ago       Romania    euornithopod
# 307  Early Cretaceous 120-110 million years ago           USA    euornithopod
# 308     Late Cretaceous 94-89 million years ago           USA     ceratopsian
#
#     length                                           taxonomy  \
# 0     8.0m  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 1     9.0m  Dinosauria Saurischia Theropoda Neotheropoda C...
# 2     6.0m  Dinosauria Ornithischia Genasauria Cerapoda Ma...
# 3     5.0m  Dinosauria Saurischia Theropoda Neotheropoda T...
# 4    12.0m  Dinosauria Saurischia Theropoda Neotheropoda T...
# ..     ...                                                ...
# 304  17.0m  Dinosauria Saurischia Sauropodomorpha Sauropod...
# 305   7.0m  Dinosauria Saurischia Sauropodomorpha Prosauro...
# 306   3.0m  Dinosauria Ornithischia Genasauria Cerapoda Or...
# 307   1.8m  Dinosauria Ornithischia Genasauria Cerapoda Or...
# 308    NaN  Dinosauria Ornithischia Genasauria Cerapoda Ma...
#
#                                               named_by       species  \
# 0    Yates Bonnan Neveling Chinsamy and Blackbeard ...      celestae
# 1                           Bonaparte and Novas (1985)   comahuensis
# 2                                      Sampson  (1995)       horneri
# 3                        Perle Norell and Clark (1999)     giganteus
# 4                          Stovall and Langston (1950)     atokensis
# ..                                                 ...           ...
# 304                Lü Li Ji Wang Zhang and Dong (2006)  jiangyiensis
# 305                                       Young (1942)        huangi
# 306                                      Nopcsa (1902)      robustus
# 307                                        Sues (1980)       schaffi
# 308                          Wolfe and Kirkland (1998)  christopheri
#
#                                                   link
# 0    https://www.nhm.ac.uk/discover/dino-directory/...
# 1    https://www.nhm.ac.uk/discover/dino-directory/...
# 2    https://www.nhm.ac.uk/discover/dino-directory/...
# 3    https://www.nhm.ac.uk/discover/dino-directory/...
# 4    https://www.nhm.ac.uk/discover/dino-directory/...
# ..                                                 ...
# 304  https://www.nhm.ac.uk/discover/dino-directory/...
# 305  https://www.nhm.ac.uk/discover/dino-directory/...
# 306  https://www.nhm.ac.uk/discover/dino-directory/...
# 307  https://www.nhm.ac.uk/discover/dino-directory/...
# 308  https://www.nhm.ac.uk/discover/dino-directory/...
#
# [309 rows x 10 columns]

# %%
df[0].isna().sum()
# Out:
# name         0
# diet         0
# period       0
# lived_in     1
# type         0
# length      18
# taxonomy     0
# named_by     0
# species      5
# link         0
# dtype: int64

# %%
df[1]
# Out:
#         occurrence_no record_type  reid_no flags  collection_no  \
# 0                   1         occ      NaN   NaN              1
# 1                   2         occ      NaN   NaN              1
# 2                   3         occ      NaN   NaN              1
# 3                   4         occ      NaN   NaN              2
# 4                   5         occ      NaN   NaN              3
# ...               ...         ...      ...   ...            ...
# 124750         165375         occ      NaN   NaN          14912
# 124751         165376         occ      NaN   NaN          14912
# 124752         165377         occ      NaN   NaN          14912
# 124753         165379         occ      NaN   NaN          14912
# 124754         165380         occ      NaN   NaN          14912
#
#          accepted_name  accepted_attr accepted_rank  accepted_no  \
# 0       Australosutura            NaN         genus        21084
# 1       Carbonocoryphe            NaN         genus        21109
# 2         Thigriffides            NaN         genus        21387
# 3          Pudoproetus            NaN         genus       177081
# 4          Pudoproetus            NaN         genus       177081
# ...                ...            ...           ...          ...
# 124750        Stygimys            NaN         genus        39846
# 124751      Catopsalis            NaN         genus        39829
# 124752       Anconodon            NaN         genus        39824
# 124753        Ptilodus            NaN         genus        39820
# 124754      Baiotomeus            NaN         genus        39811
#
#        early_interval  ...         motility           life_habit  \
# 0             Ivorian  ...      fast-moving  low-level epifaunal
# 1             Ivorian  ...      fast-moving  low-level epifaunal
# 2             Ivorian  ...      fast-moving  low-level epifaunal
# 3             Ivorian  ...      fast-moving  low-level epifaunal
# 4             Ivorian  ...      fast-moving  low-level epifaunal
# ...               ...  ...              ...                  ...
# 124750    Torrejonian  ...  actively mobile             arboreal
# 124751    Torrejonian  ...  actively mobile             arboreal
# 124752    Torrejonian  ...  actively mobile             arboreal
# 124753    Torrejonian  ...  actively mobile             arboreal
# 124754    Torrejonian  ...              NaN                  NaN
#
#                 vision            diet  reproduction  \
# 0       well-developed  deposit feeder           NaN
# 1       well-developed  deposit feeder           NaN
# 2       well-developed  deposit feeder           NaN
# 3       well-developed  deposit feeder           NaN
# 4       well-developed  deposit feeder           NaN
# ...                ...             ...           ...
# 124750             NaN        omnivore           NaN
# 124751             NaN       herbivore           NaN
# 124752             NaN        omnivore           NaN
# 124753             NaN       herbivore           NaN
# 124754             NaN             NaN           NaN
#
#                          ontogeny             composition architecture  \
# 0       molting,addition of parts  low Mg calcite, chitin          NaN
# 1       molting,addition of parts  low Mg calcite, chitin          NaN
# 2       molting,addition of parts  low Mg calcite, chitin          NaN
# 3       molting,addition of parts  low Mg calcite, chitin          NaN
# 4       molting,addition of parts  low Mg calcite, chitin          NaN
# ...                           ...                     ...          ...
# 124750                        NaN          hydroxyapatite          NaN
# 124751                        NaN          hydroxyapatite          NaN
# 124752                        NaN          hydroxyapatite          NaN
# 124753                        NaN          hydroxyapatite          NaN
# 124754                        NaN                     NaN          NaN
#
#        thickness reinforcement
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 124750       NaN           NaN
# 124751       NaN           NaN
# 124752       NaN           NaN
# 124753       NaN           NaN
# 124754       NaN           NaN
#
# [124755 rows x 112 columns]

# %%
df[1] = df[1].drop(columns = ['reinforcement','reid_no', 'flags', 'accepted_rank', 'accepted_attr', 'ref_author', 'plant_organ', 'plant_organ2', 'collection_subset', 'collection_aka', 'county', 'protected', 'stratgroup', 'stratscale','reproduction','ontogeny', 'composition', 'architecture', 'thickness', 'collection_dates', 'collection_comments', 'taxon_environment', 'environment_basis', 'collectors'])
df[1]
# Out:
#         occurrence_no record_type  collection_no   accepted_name  accepted_no  \
# 0                   1         occ              1  Australosutura        21084
# 1                   2         occ              1  Carbonocoryphe        21109
# 2                   3         occ              1    Thigriffides        21387
# 3                   4         occ              2     Pudoproetus       177081
# 4                   5         occ              3     Pudoproetus       177081
# ...               ...         ...            ...             ...          ...
# 124750         165375         occ          14912        Stygimys        39846
# 124751         165376         occ          14912      Catopsalis        39829
# 124752         165377         occ          14912       Anconodon        39824
# 124753         165379         occ          14912        Ptilodus        39820
# 124754         165380         occ          14912      Baiotomeus        39811
#
#        early_interval late_interval  max_ma  min_ma  ref_pubyr  ...  \
# 0             Ivorian           NaN   353.8   345.3     1998.0  ...
# 1             Ivorian           NaN   353.8   345.3     1998.0  ...
# 2             Ivorian           NaN   353.8   345.3     1998.0  ...
# 3             Ivorian           NaN   353.8   345.3     1998.0  ...
# 4             Ivorian           NaN   353.8   345.3     1998.0  ...
# ...               ...           ...     ...     ...        ...  ...
# 124750    Torrejonian           NaN    63.3    61.7     1981.0  ...
# 124751    Torrejonian           NaN    63.3    61.7     1981.0  ...
# 124752    Torrejonian           NaN    63.3    61.7     1981.0  ...
# 124753    Torrejonian           NaN    63.3    61.7     1981.0  ...
# 124754    Torrejonian           NaN    63.3    61.7     1987.0  ...
#
#         collection_methods museum collection_coverage collection_size  \
# 0                      NaN   USNM                 NaN             NaN
# 1                      NaN   USNM                 NaN             NaN
# 2                      NaN   USNM                 NaN             NaN
# 3                      NaN   USNM                 NaN             NaN
# 4                      NaN   USNM                 NaN             NaN
# ...                    ...    ...                 ...             ...
# 124750                 NaN    NaN                 NaN  1687 specimens
# 124751                 NaN    NaN                 NaN  1687 specimens
# 124752                 NaN    NaN                 NaN  1687 specimens
# 124753                 NaN    NaN                 NaN  1687 specimens
# 124754                 NaN    NaN                 NaN             NaN
#
#        rock_censused                                  taxonomy_comments  \
# 0                NaN                                    Trilobites only
# 1                NaN                                    Trilobites only
# 2                NaN                                    Trilobites only
# 3                NaN                                    Trilobites only
# 4                NaN                                    Trilobites only
# ...              ...                                                ...
# 124750           NaN  >I have used Van Valen's 1978 list of condylar...
# 124751           NaN  >I have used Van Valen's 1978 list of condylar...
# 124752           NaN  >I have used Van Valen's 1978 list of condylar...
# 124753           NaN  >I have used Van Valen's 1978 list of condylar...
# 124754           NaN                                                NaN
#
#                motility           life_habit          vision            diet
# 0           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 1           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 2           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 3           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 4           fast-moving  low-level epifaunal  well-developed  deposit feeder
# ...                 ...                  ...             ...             ...
# 124750  actively mobile             arboreal             NaN        omnivore
# 124751  actively mobile             arboreal             NaN       herbivore
# 124752  actively mobile             arboreal             NaN        omnivore
# 124753  actively mobile             arboreal             NaN       herbivore
# 124754              NaN                  NaN             NaN             NaN
#
# [124755 rows x 88 columns]

# %%
for i in df[1].columns:
    if df[1][str(i)].isna().sum() > (df[1].shape[0] * 3/4):
        del df[1][str(i)]
df[1].isna().sum()
# Out:
# occurrence_no              0
# record_type                0
# collection_no              0
# accepted_name              0
# accepted_no                0
# early_interval             0
# max_ma                     0
# min_ma                     0
# ref_pubyr                 90
# reference_no               0
# phylum                  2343
# class                   5095
# order                  13754
# family                 10322
# genus                      0
# abund_value            73030
# abund_unit             73065
# lng                        0
# lat                        0
# collection_name            6
# cc                      1581
# state                  21564
# latlng_basis           49302
# latlng_precision           1
# geogscale              17092
# geogcomments           28718
# paleomodel                 1
# paleolng                 429
# paleolat                 429
# geoplate                   1
# cc.1                    1582
# formation              21160
# member                 80930
# zone                   89593
# localsection           90207
# stratcomments          54485
# lithdescript           70091
# lithology1              8952
# lithadj1               52500
# lithification1         67973
# minor_lithology1       76770
# lithology2             88853
# environment            15882
# tectonic_setting       81027
# geology_comments       86608
# assembl_comps          76999
# pres_mode              40132
# collection_type         9756
# collection_methods     56290
# collection_coverage    70679
# taxonomy_comments      78503
# motility                3996
# life_habit              4386
# vision                 10666
# diet                    4965
# dtype: int64

# %%
df[0]['name'] = df[0]['name'].str.capitalize()
df[1].rename(columns = {'accepted_name':'name'},inplace=True)
df[1]
# Out:
#         occurrence_no record_type  collection_no            name  accepted_no  \
# 0                   1         occ              1  Australosutura        21084
# 1                   2         occ              1  Carbonocoryphe        21109
# 2                   3         occ              1    Thigriffides        21387
# 3                   4         occ              2     Pudoproetus       177081
# 4                   5         occ              3     Pudoproetus       177081
# ...               ...         ...            ...             ...          ...
# 124750         165375         occ          14912        Stygimys        39846
# 124751         165376         occ          14912      Catopsalis        39829
# 124752         165377         occ          14912       Anconodon        39824
# 124753         165379         occ          14912        Ptilodus        39820
# 124754         165380         occ          14912      Baiotomeus        39811
#
#        early_interval  max_ma  min_ma  ref_pubyr  reference_no  ...  \
# 0             Ivorian   353.8   345.3     1998.0             1  ...
# 1             Ivorian   353.8   345.3     1998.0             1  ...
# 2             Ivorian   353.8   345.3     1998.0             1  ...
# 3             Ivorian   353.8   345.3     1998.0             1  ...
# 4             Ivorian   353.8   345.3     1998.0             1  ...
# ...               ...     ...     ...        ...           ...  ...
# 124750    Torrejonian    63.3    61.7     1981.0          2953  ...
# 124751    Torrejonian    63.3    61.7     1981.0          2953  ...
# 124752    Torrejonian    63.3    61.7     1981.0          2953  ...
# 124753    Torrejonian    63.3    61.7     1981.0          2953  ...
# 124754    Torrejonian    63.3    61.7     1987.0          2160  ...
#
#        assembl_comps pres_mode        collection_type collection_methods  \
# 0                NaN      body              taxonomic                NaN
# 1                NaN      body              taxonomic                NaN
# 2                NaN      body              taxonomic                NaN
# 3                NaN      body              taxonomic                NaN
# 4                NaN      body              taxonomic                NaN
# ...              ...       ...                    ...                ...
# 124750           NaN      body  general faunal/floral                NaN
# 124751           NaN      body  general faunal/floral                NaN
# 124752           NaN      body  general faunal/floral                NaN
# 124753           NaN      body  general faunal/floral                NaN
# 124754           NaN       NaN                    NaN                NaN
#
#        collection_coverage                                  taxonomy_comments  \
# 0                      NaN                                    Trilobites only
# 1                      NaN                                    Trilobites only
# 2                      NaN                                    Trilobites only
# 3                      NaN                                    Trilobites only
# 4                      NaN                                    Trilobites only
# ...                    ...                                                ...
# 124750                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124751                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124752                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124753                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124754                 NaN                                                NaN
#
#                motility           life_habit          vision            diet
# 0           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 1           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 2           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 3           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 4           fast-moving  low-level epifaunal  well-developed  deposit feeder
# ...                 ...                  ...             ...             ...
# 124750  actively mobile             arboreal             NaN        omnivore
# 124751  actively mobile             arboreal             NaN       herbivore
# 124752  actively mobile             arboreal             NaN        omnivore
# 124753  actively mobile             arboreal             NaN       herbivore
# 124754              NaN                  NaN             NaN             NaN
#
# [124755 rows x 55 columns]

# %%
df[1]['diet'].unique()
# Out:
# array(['deposit feeder', 'suspension feeder', 'omnivore', 'carnivore',
#        nan, 'grazer', 'deposit feeder, suspension feeder', 'detritivore',
#        'parasite', 'detritivore, omnivore', 'detritivore, carnivore',
#        'suspension feeder, photosymbiotic', 'herbivore', 'microcarnivore',
#        '"photoautotroph"', 'detritivore, grazer',
#        'coprophage, deposit feeder', 'carnivore, suspension feeder',
#        'detritivore, suspension feeder', 'coprophage', 'chemosymbiotic',
#        'grazer, deposit feeder', 'deposit feeder, chemosymbiotic',
#        'suspension feeder, detritivore', 'browser, omnivore',
#        'photosymbiotic', 'grazer, suspension feeder',
#        'microcarnivore, photosymbiotic',
#        'chemosymbiotic, suspension feeder', 'omnivore, grazer',
#        'photosymbiotic, suspension feeder', 'deposit feeder, detritivore',
#        'grazer, omnivore', 'photosymbiotic, microcarnivore',
#        'grazer, carnivore', 'durophage, carnivore',
#        'carnivore, detritivore', 'carnivore, parasite', 'osmotroph',
#        'insectivore', 'folivore', 'carnivore, omnivore',
#        'frugivore, folivore', 'browser, grazer', 'frugivore, omnivore',
#        'browser', 'suspension feeder, osmotroph',
#        'osmotroph, suspension feeder', 'osmotroph, "photoautotroph"',
#        'C3 autotroph', 'herbivore, carnivore', 'frugivore, grazer',
#        'grazer, browser', 'insectivore, carnivore',
#        'granivore, frugivore', 'herbivore, insectivore',
#        'herbivore, frugivore', 'piscivore, carnivore',
#        'carnivore, piscivore', 'piscivore', 'carnivore, insectivore',
#        'herbivore, herbivore', 'parasite, carnivore',
#        'omnivore, carnivore', 'carnivore, durophage',
#        'omnivore, frugivore', 'durophage', 'insectivore, omnivore',
#        'omnivore, herbivore', 'piscivore, durophage'], dtype=object)

# %%
combined = pd.merge(df[1],df[0], on='name',how='outer')
combined.drop_duplicates().shape
# Out:
# (125031, 64)

# %%
pd.set_option('display.max_columns', None)

# %%
dino_df = df[1]
dino_df['diet'].dtype
# Out:
# dtype('O')

# %%
def classify_diet(diet):
    if 'carnivore' in diet:
        return 'carnivore'
    elif 'omnivore' in diet:
        return 'omnivore'
    else:
        return 'herbivore'

diet_class = []
for i in range(0,len(dino_df['diet'])):
    if pd.isna(dino_df['diet'].iloc[i]):
        diet_class.append(dino_df['diet'].iloc[i])
    else:
        diet_class.append(classify_diet(dino_df['diet'].iloc[i]))
dino_df['diet_class'] = diet_class

# %%
dino_df
# Out:
#         occurrence_no record_type  collection_no            name  accepted_no  \
# 0                   1         occ              1  Australosutura        21084
# 1                   2         occ              1  Carbonocoryphe        21109
# 2                   3         occ              1    Thigriffides        21387
# 3                   4         occ              2     Pudoproetus       177081
# 4                   5         occ              3     Pudoproetus       177081
# ...               ...         ...            ...             ...          ...
# 124750         165375         occ          14912        Stygimys        39846
# 124751         165376         occ          14912      Catopsalis        39829
# 124752         165377         occ          14912       Anconodon        39824
# 124753         165379         occ          14912        Ptilodus        39820
# 124754         165380         occ          14912      Baiotomeus        39811
#
#        early_interval  max_ma  min_ma  ref_pubyr  reference_no      phylum  \
# 0             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 1             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 2             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 3             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 4             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# ...               ...     ...     ...        ...           ...         ...
# 124750    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124751    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124752    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124753    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124754    Torrejonian    63.3    61.7     1987.0          2160    Chordata
#
#             class             order           family           genus  \
# 0       Trilobita          Proetida  Brachymetopidae  Australosutura
# 1       Trilobita          Proetida        Proetidae  Carbonocoryphe
# 2       Trilobita          Proetida        Proetidae    Thigriffides
# 3       Trilobita          Proetida        Proetidae     Pudoproetus
# 4       Trilobita          Proetida        Proetidae     Pudoproetus
# ...           ...               ...              ...             ...
# 124750   Mammalia  Multituberculata  Eucosmodontidae        Stygimys
# 124751   Mammalia  Multituberculata  Taeniolabididae      Catopsalis
# 124752   Mammalia  Multituberculata   Cimolodontidae       Anconodon
# 124753   Mammalia  Multituberculata    Ptilodontidae        Ptilodus
# 124754   Mammalia  Multituberculata    Ptilodontidae      Baiotomeus
#
#        abund_value abund_unit         lng        lat    collection_name  cc  \
# 0                4  specimens  -98.099998  31.000000          USNM 9047  US
# 1                1  specimens  -98.099998  31.000000          USNM 9047  US
# 2                2  specimens  -98.099998  31.000000          USNM 9047  US
# 3                6  specimens  -98.099998  31.000000          USNM 9048  US
# 4                8  specimens  -98.099998  31.000000          USNM 9044  US
# ...            ...        ...         ...        ...                ...  ..
# 124750         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124751         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124752         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124753         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124754         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
#
#           state             latlng_basis latlng_precision         geogscale  \
# 0         Texas                      NaN                1               NaN
# 1         Texas                      NaN                1               NaN
# 2         Texas                      NaN                1               NaN
# 3         Texas                      NaN                1               NaN
# 4         Texas                      NaN                1               NaN
# ...         ...                      ...              ...               ...
# 124750  Wyoming  based on political unit                1  small collection
# 124751  Wyoming  based on political unit                1  small collection
# 124752  Wyoming  based on political unit                1  small collection
# 124753  Wyoming  based on political unit                1  small collection
# 124754  Wyoming                      NaN              NaN               NaN
#
#              geogcomments paleomodel  paleolng  paleolat geoplate cc.1  \
# 0       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 1       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 2       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 3       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 4       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# ...                   ...        ...       ...       ...      ...  ...
# 124750      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124751      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124752      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124753      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124754                NaN        NaN       NaN       NaN      NaN  NaN
#
#                 formation member  \
# 0       Chappel Limestone    NaN
# 1       Chappel Limestone    NaN
# 2       Chappel Limestone    NaN
# 3       Chappel Limestone    NaN
# 4       Chappel Limestone    NaN
# ...                   ...    ...
# 124750                NaN    NaN
# 124751                NaN    NaN
# 124752                NaN    NaN
# 124753                NaN    NaN
# 124754                NaN    NaN
#
#                                                      zone localsection  \
# 0       S. isostichia - crenulata through S. anchorali...          NaN
# 1       S. isostichia - crenulata through S. anchorali...          NaN
# 2       S. isostichia - crenulata through S. anchorali...          NaN
# 3       S. isostichia - crenulata through S. anchorali...          NaN
# 4       S. isostichia - crenulata through S. anchorali...          NaN
# ...                                                   ...          ...
# 124750                                                NaN        Clark
# 124751                                                NaN        Clark
# 124752                                                NaN        Clark
# 124753                                                NaN        Clark
# 124754                                                NaN          NaN
#
#                                             stratcomments lithdescript  \
# 0                          Late Kinderhookian and Osagean          NaN
# 1                          Late Kinderhookian and Osagean          NaN
# 2                          Late Kinderhookian and Osagean          NaN
# 3                          Late Kinderhookian and Osagean          NaN
# 4                          Late Kinderhookian and Osagean          NaN
# ...                                                   ...          ...
# 124750  in a stratigraphically isolated reversed polar...          NaN
# 124751  in a stratigraphically isolated reversed polar...          NaN
# 124752  in a stratigraphically isolated reversed polar...          NaN
# 124753  in a stratigraphically isolated reversed polar...          NaN
# 124754                                                NaN          NaN
#
#          lithology1 lithadj1 lithification1 minor_lithology1 lithology2  \
# 0       "carbonate"      NaN            NaN              NaN        NaN
# 1       "carbonate"      NaN            NaN              NaN        NaN
# 2       "carbonate"      NaN            NaN              NaN        NaN
# 3       "carbonate"      NaN            NaN              NaN        NaN
# 4       "carbonate"      NaN            NaN              NaN        NaN
# ...             ...      ...            ...              ...        ...
# 124750          NaN      NaN            NaN              NaN        NaN
# 124751          NaN      NaN            NaN              NaN        NaN
# 124752          NaN      NaN            NaN              NaN        NaN
# 124753          NaN      NaN            NaN              NaN        NaN
# 124754          NaN      NaN            NaN              NaN        NaN
#
#                environment tectonic_setting geology_comments assembl_comps  \
# 0            marine indet.              NaN              NaN           NaN
# 1            marine indet.              NaN              NaN           NaN
# 2            marine indet.              NaN              NaN           NaN
# 3            marine indet.              NaN              NaN           NaN
# 4            marine indet.              NaN              NaN           NaN
# ...                    ...              ...              ...           ...
# 124750  terrestrial indet.              NaN              NaN           NaN
# 124751  terrestrial indet.              NaN              NaN           NaN
# 124752  terrestrial indet.              NaN              NaN           NaN
# 124753  terrestrial indet.              NaN              NaN           NaN
# 124754                 NaN              NaN              NaN           NaN
#
#        pres_mode        collection_type collection_methods  \
# 0           body              taxonomic                NaN
# 1           body              taxonomic                NaN
# 2           body              taxonomic                NaN
# 3           body              taxonomic                NaN
# 4           body              taxonomic                NaN
# ...          ...                    ...                ...
# 124750      body  general faunal/floral                NaN
# 124751      body  general faunal/floral                NaN
# 124752      body  general faunal/floral                NaN
# 124753      body  general faunal/floral                NaN
# 124754       NaN                    NaN                NaN
#
#        collection_coverage                                  taxonomy_comments  \
# 0                      NaN                                    Trilobites only
# 1                      NaN                                    Trilobites only
# 2                      NaN                                    Trilobites only
# 3                      NaN                                    Trilobites only
# 4                      NaN                                    Trilobites only
# ...                    ...                                                ...
# 124750                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124751                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124752                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124753                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124754                 NaN                                                NaN
#
#                motility           life_habit          vision            diet  \
# 0           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 1           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 2           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 3           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 4           fast-moving  low-level epifaunal  well-developed  deposit feeder
# ...                 ...                  ...             ...             ...
# 124750  actively mobile             arboreal             NaN        omnivore
# 124751  actively mobile             arboreal             NaN       herbivore
# 124752  actively mobile             arboreal             NaN        omnivore
# 124753  actively mobile             arboreal             NaN       herbivore
# 124754              NaN                  NaN             NaN             NaN
#
#        diet_class
# 0       herbivore
# 1       herbivore
# 2       herbivore
# 3       herbivore
# 4       herbivore
# ...           ...
# 124750   omnivore
# 124751  herbivore
# 124752   omnivore
# 124753  herbivore
# 124754        NaN
#
# [124755 rows x 56 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dino_df['early_interval'].mode()
# Out:
# 0    Late Maastrichtian
# Name: early_interval, dtype: object

# %%
dino_df['diet_class'].mode()
# Out:
# 0    herbivore
# Name: diet_class, dtype: object

# %%
dino_df.groupby('early_interval').count()
# Out:
#                 occurrence_no  record_type  collection_no  name  accepted_no  \
# early_interval
# Aalenian                   14           14             14    14           14
# Actonian                  454          454            454   454          454
# Adavere                     5            5              5     5            5
# Aeronian                  369          369            369   369          369
# Albian                    752          752            752   752          752
# ...                       ...          ...            ...   ...          ...
# Zahorany                    1            1              1     1            1
# Zanclean                    2            2              2     2            2
# Zechstein                   1            1              1     1            1
# Zhanarykian                11           11             11    11           11
# Zlichovian                213          213            213   213          213
#
#                 max_ma  min_ma  ref_pubyr  reference_no  phylum  class  order  \
# early_interval
# Aalenian            14      14         14            14      14     14     14
# Actonian           454     454        454           454     446    445    438
# Adavere              5       5          5             5       5      5      5
# Aeronian           369     369        369           369     352    353    352
# Albian             752     752        752           752     743    740    665
# ...                ...     ...        ...           ...     ...    ...    ...
# Zahorany             1       1          1             1       1      1      1
# Zanclean             2       2          2             2       2      1      1
# Zechstein            1       1          1             1       0      0      0
# Zhanarykian         11      11         11            11      11     11     11
# Zlichovian         213     213        213           213     208    208    210
#
#                 family  genus  abund_value  abund_unit  lng  lat  \
# early_interval
# Aalenian            14     14           14          14   14   14
# Actonian           410    454            0           0  454  454
# Adavere              5      5            0           0    5    5
# Aeronian           334    369          121         121  369  369
# Albian             722    752          383         383  752  752
# ...                ...    ...          ...         ...  ...  ...
# Zahorany             1      1            0           0    1    1
# Zanclean             2      2            0           0    2    2
# Zechstein            0      1            0           0    1    1
# Zhanarykian         11     11            0           0   11   11
# Zlichovian         211    213           57          57  213  213
#
#                 collection_name   cc  state  latlng_basis  latlng_precision  \
# early_interval
# Aalenian                     14   14      0            14                14
# Actonian                    454  454    416             0               454
# Adavere                       5    5      0             5                 5
# Aeronian                    369  369    115           335               369
# Albian                      752  748    568           503               752
# ...                         ...  ...    ...           ...               ...
# Zahorany                      1    1      1             0                 1
# Zanclean                      2    2      2             2                 2
# Zechstein                     1    1      1             1                 1
# Zhanarykian                  11    0      0            11                11
# Zlichovian                  213  213    183            11               213
#
#                 geogscale  geogcomments  paleomodel  paleolng  paleolat  \
# early_interval
# Aalenian               14            14          14        14        14
# Actonian              454           452         454       454       454
# Adavere                 5             5           5         5         5
# Aeronian              360           350         369       369       369
# Albian                582           743         752       739       739
# ...                   ...           ...         ...       ...       ...
# Zahorany                1             1           1         1         1
# Zanclean                2             2           2         2         2
# Zechstein               1             1           1         1         1
# Zhanarykian            11            11          11        11        11
# Zlichovian             35           189         213       213       213
#
#                 geoplate  cc.1  formation  member  zone  localsection  \
# early_interval
# Aalenian              14    14         14       0     0             0
# Actonian             454   454        286      46     0            23
# Adavere                5     5          0       0     0             0
# Aeronian             369   369        349     173   110             2
# Albian               752   748        553      87     2           456
# ...                  ...   ...        ...     ...   ...           ...
# Zahorany               1     1          1       0     0             0
# Zanclean               2     2          2       0     0             0
# Zechstein              1     1          1       1     0             0
# Zhanarykian           11     0         11       0    11            11
# Zlichovian           213   213          5     178    35             0
#
#                 stratcomments  lithdescript  lithology1  lithadj1  \
# early_interval
# Aalenian                   14            14          14        14
# Actonian                  171           235         454       308
# Adavere                     0             5           5         5
# Aeronian                  179           298         369       188
# Albian                    204            10         727       690
# ...                       ...           ...         ...       ...
# Zahorany                    1             0           1         1
# Zanclean                    2             2           2         2
# Zechstein                   1             1           1         1
# Zhanarykian                11            11          11         0
# Zlichovian                 30           189         213       183
#
#                 lithification1  minor_lithology1  lithology2  environment  \
# early_interval
# Aalenian                     0                 0           0           14
# Actonian                   454               178         196          454
# Adavere                      5                 5           0            5
# Aeronian                    85                73         272          369
# Albian                      17               256          25          475
# ...                        ...               ...         ...          ...
# Zahorany                     0                 0           0            1
# Zanclean                     0                 0           2            2
# Zechstein                    0                 0           0            1
# Zhanarykian                 11                 0           0           11
# Zlichovian                   0               118           5          213
#
#                 tectonic_setting  geology_comments  assembl_comps  pres_mode  \
# early_interval
# Aalenian                      14                 0             14         14
# Actonian                       0               240             37         37
# Adavere                        0                 0              0          0
# Aeronian                      10               258            173        204
# Albian                       442                32            294        309
# ...                          ...               ...            ...        ...
# Zahorany                       0                 0              1          1
# Zanclean                       0                 2              2          2
# Zechstein                      0                 1              1          1
# Zhanarykian                    0                11             11         11
# Zlichovian                    24               178              0         46
#
#                 collection_type  collection_methods  collection_coverage  \
# early_interval
# Aalenian                     14                  14                   14
# Actonian                    444                   0                  208
# Adavere                       5                   0                    5
# Aeronian                    367                  49                  145
# Albian                      752                 472                  476
# ...                         ...                 ...                  ...
# Zahorany                      1                   1                    0
# Zanclean                      2                   2                    2
# Zechstein                     1                   1                    0
# Zhanarykian                  11                  11                    0
# Zlichovian                  213                  70                  189
#
#                 taxonomy_comments  motility  life_habit  vision  diet  \
# early_interval
# Aalenian                        0        14          14      14    14
# Actonian                        0       450         450     445   451
# Adavere                         0         5           5       5     5
# Aeronian                      193       362         362     346   365
# Albian                         14       743         740     693   742
# ...                           ...       ...         ...     ...   ...
# Zahorany                        1         1           1       1     1
# Zanclean                        2         2           1       0     2
# Zechstein                       0         0           0       0     0
# Zhanarykian                     0        11          11      11    11
# Zlichovian                    208       208         208     212   212
#
#                 diet_class
# early_interval
# Aalenian                14
# Actonian               451
# Adavere                  5
# Aeronian               365
# Albian                 742
# ...                    ...
# Zahorany                 1
# Zanclean                 2
# Zechstein                0
# Zhanarykian             11
# Zlichovian             212
#
# [386 rows x 55 columns]

# %%
pie_data = dino_df.groupby('early_interval').count().sort_values(by='occurrence_no',ascending = False).reset_index()[:10]
#plot = pie_data.plot.pie(y='occurrence_no', figsize=(10, 20))

sns.set_style("whitegrid") # Set style for chart
plt.figure(figsize=(6,6)) # Set figure size
plt.pie(pie_data['occurrence_no'], labels=pie_data['early_interval']) # Create pie chart
plt.show() # Show chart

# %%
dino_df['mass_range'] = dino_df['max_ma'] - dino_df['min_ma']
# Out:
#         occurrence_no record_type  collection_no            name  accepted_no  \
# 0                   1         occ              1  Australosutura        21084
# 1                   2         occ              1  Carbonocoryphe        21109
# 2                   3         occ              1    Thigriffides        21387
# 3                   4         occ              2     Pudoproetus       177081
# 4                   5         occ              3     Pudoproetus       177081
# ...               ...         ...            ...             ...          ...
# 124750         165375         occ          14912        Stygimys        39846
# 124751         165376         occ          14912      Catopsalis        39829
# 124752         165377         occ          14912       Anconodon        39824
# 124753         165379         occ          14912        Ptilodus        39820
# 124754         165380         occ          14912      Baiotomeus        39811
#
#        early_interval  max_ma  min_ma  ref_pubyr  reference_no      phylum  \
# 0             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 1             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 2             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 3             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# 4             Ivorian   353.8   345.3     1998.0             1  Arthropoda
# ...               ...     ...     ...        ...           ...         ...
# 124750    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124751    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124752    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124753    Torrejonian    63.3    61.7     1981.0          2953    Chordata
# 124754    Torrejonian    63.3    61.7     1987.0          2160    Chordata
#
#             class             order           family           genus  \
# 0       Trilobita          Proetida  Brachymetopidae  Australosutura
# 1       Trilobita          Proetida        Proetidae  Carbonocoryphe
# 2       Trilobita          Proetida        Proetidae    Thigriffides
# 3       Trilobita          Proetida        Proetidae     Pudoproetus
# 4       Trilobita          Proetida        Proetidae     Pudoproetus
# ...           ...               ...              ...             ...
# 124750   Mammalia  Multituberculata  Eucosmodontidae        Stygimys
# 124751   Mammalia  Multituberculata  Taeniolabididae      Catopsalis
# 124752   Mammalia  Multituberculata   Cimolodontidae       Anconodon
# 124753   Mammalia  Multituberculata    Ptilodontidae        Ptilodus
# 124754   Mammalia  Multituberculata    Ptilodontidae      Baiotomeus
#
#        abund_value abund_unit         lng        lat    collection_name  cc  \
# 0                4  specimens  -98.099998  31.000000          USNM 9047  US
# 1                1  specimens  -98.099998  31.000000          USNM 9047  US
# 2                2  specimens  -98.099998  31.000000          USNM 9047  US
# 3                6  specimens  -98.099998  31.000000          USNM 9048  US
# 4                8  specimens  -98.099998  31.000000          USNM 9044  US
# ...            ...        ...         ...        ...                ...  ..
# 124750         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124751         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124752         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124753         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
# 124754         NaN        NaN -109.000000  44.299999  Rock Bench Quarry  US
#
#           state             latlng_basis latlng_precision         geogscale  \
# 0         Texas                      NaN                1               NaN
# 1         Texas                      NaN                1               NaN
# 2         Texas                      NaN                1               NaN
# 3         Texas                      NaN                1               NaN
# 4         Texas                      NaN                1               NaN
# ...         ...                      ...              ...               ...
# 124750  Wyoming  based on political unit                1  small collection
# 124751  Wyoming  based on political unit                1  small collection
# 124752  Wyoming  based on political unit                1  small collection
# 124753  Wyoming  based on political unit                1  small collection
# 124754  Wyoming                      NaN              NaN               NaN
#
#              geogcomments paleomodel  paleolng  paleolat geoplate cc.1  \
# 0       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 1       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 2       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 3       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# 4       Near San Saba, TX     gp_mid    -65.59    -27.46      101   US
# ...                   ...        ...       ...       ...      ...  ...
# 124750      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124751      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124752      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124753      Bighorn Basin     gp_mid    -73.72     54.42    101.0   US
# 124754                NaN        NaN       NaN       NaN      NaN  NaN
#
#                 formation member  \
# 0       Chappel Limestone    NaN
# 1       Chappel Limestone    NaN
# 2       Chappel Limestone    NaN
# 3       Chappel Limestone    NaN
# 4       Chappel Limestone    NaN
# ...                   ...    ...
# 124750                NaN    NaN
# 124751                NaN    NaN
# 124752                NaN    NaN
# 124753                NaN    NaN
# 124754                NaN    NaN
#
#                                                      zone localsection  \
# 0       S. isostichia - crenulata through S. anchorali...          NaN
# 1       S. isostichia - crenulata through S. anchorali...          NaN
# 2       S. isostichia - crenulata through S. anchorali...          NaN
# 3       S. isostichia - crenulata through S. anchorali...          NaN
# 4       S. isostichia - crenulata through S. anchorali...          NaN
# ...                                                   ...          ...
# 124750                                                NaN        Clark
# 124751                                                NaN        Clark
# 124752                                                NaN        Clark
# 124753                                                NaN        Clark
# 124754                                                NaN          NaN
#
#                                             stratcomments lithdescript  \
# 0                          Late Kinderhookian and Osagean          NaN
# 1                          Late Kinderhookian and Osagean          NaN
# 2                          Late Kinderhookian and Osagean          NaN
# 3                          Late Kinderhookian and Osagean          NaN
# 4                          Late Kinderhookian and Osagean          NaN
# ...                                                   ...          ...
# 124750  in a stratigraphically isolated reversed polar...          NaN
# 124751  in a stratigraphically isolated reversed polar...          NaN
# 124752  in a stratigraphically isolated reversed polar...          NaN
# 124753  in a stratigraphically isolated reversed polar...          NaN
# 124754                                                NaN          NaN
#
#          lithology1 lithadj1 lithification1 minor_lithology1 lithology2  \
# 0       "carbonate"      NaN            NaN              NaN        NaN
# 1       "carbonate"      NaN            NaN              NaN        NaN
# 2       "carbonate"      NaN            NaN              NaN        NaN
# 3       "carbonate"      NaN            NaN              NaN        NaN
# 4       "carbonate"      NaN            NaN              NaN        NaN
# ...             ...      ...            ...              ...        ...
# 124750          NaN      NaN            NaN              NaN        NaN
# 124751          NaN      NaN            NaN              NaN        NaN
# 124752          NaN      NaN            NaN              NaN        NaN
# 124753          NaN      NaN            NaN              NaN        NaN
# 124754          NaN      NaN            NaN              NaN        NaN
#
#                environment tectonic_setting geology_comments assembl_comps  \
# 0            marine indet.              NaN              NaN           NaN
# 1            marine indet.              NaN              NaN           NaN
# 2            marine indet.              NaN              NaN           NaN
# 3            marine indet.              NaN              NaN           NaN
# 4            marine indet.              NaN              NaN           NaN
# ...                    ...              ...              ...           ...
# 124750  terrestrial indet.              NaN              NaN           NaN
# 124751  terrestrial indet.              NaN              NaN           NaN
# 124752  terrestrial indet.              NaN              NaN           NaN
# 124753  terrestrial indet.              NaN              NaN           NaN
# 124754                 NaN              NaN              NaN           NaN
#
#        pres_mode        collection_type collection_methods  \
# 0           body              taxonomic                NaN
# 1           body              taxonomic                NaN
# 2           body              taxonomic                NaN
# 3           body              taxonomic                NaN
# 4           body              taxonomic                NaN
# ...          ...                    ...                ...
# 124750      body  general faunal/floral                NaN
# 124751      body  general faunal/floral                NaN
# 124752      body  general faunal/floral                NaN
# 124753      body  general faunal/floral                NaN
# 124754       NaN                    NaN                NaN
#
#        collection_coverage                                  taxonomy_comments  \
# 0                      NaN                                    Trilobites only
# 1                      NaN                                    Trilobites only
# 2                      NaN                                    Trilobites only
# 3                      NaN                                    Trilobites only
# 4                      NaN                                    Trilobites only
# ...                    ...                                                ...
# 124750                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124751                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124752                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124753                 NaN  >I have used Van Valen's 1978 list of condylar...
# 124754                 NaN                                                NaN
#
#                motility           life_habit          vision            diet  \
# 0           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 1           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 2           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 3           fast-moving  low-level epifaunal  well-developed  deposit feeder
# 4           fast-moving  low-level epifaunal  well-developed  deposit feeder
# ...                 ...                  ...             ...             ...
# 124750  actively mobile             arboreal             NaN        omnivore
# 124751  actively mobile             arboreal             NaN       herbivore
# 124752  actively mobile             arboreal             NaN        omnivore
# 124753  actively mobile             arboreal             NaN       herbivore
# 124754              NaN                  NaN             NaN             NaN
#
#        diet_class  mass_range
# 0       herbivore         8.5
# 1       herbivore         8.5
# 2       herbivore         8.5
# 3       herbivore         8.5
# 4       herbivore         8.5
# ...           ...         ...
# 124750   omnivore         1.6
# 124751  herbivore         1.6
# 124752   omnivore         1.6
# 124753  herbivore         1.6
# 124754        NaN         1.6
#
# [124755 rows x 57 columns]
